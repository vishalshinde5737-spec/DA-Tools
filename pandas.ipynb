# %% [markdown]
# ### pandas
#
# > Pandas is a powerfull python library for manipulation array of data alanaysis of data
#
# >Its a open source library
#
# >fast(built on top of numpy),flexible(different resource),productive library

# %% [markdown]
# #### Inatall

# %%
! pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# #### Series --One dimentional  array(data structure) with  lable

# %%
l1=[1,2,3,4,5]
type(l1)
# Out:
# list

# %%
s=pd.Series(l1,index=["a","b","c","d","e"],name="My series")

# %%
s['a']
# Out:
# np.int64(1)

# %%
type(s)
# Out:
# pandas.Series

# %% [markdown]
# >Note: Index in Series are imuutable(cant change)

# %%
s.index[0]
# Out:
# 'a'

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
# changung the index of pandas series

s.rename(index={'b':'y'},inplace=True)

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: My series, dtype: int64

# %% [markdown]
# **DataFrame - Its a 2d array (just like tables)**

# %%
dict1={'name':['Prem','Ashok','Mayure','Vishal'],
     'age':[18,17,17,19],
      'marks':[85,88,87,92],
       'role':['Rider','Gamer','vloger','Editor'] }


df=pd.DataFrame(dict1)
type(df)
# Out:
# pandas.DataFrame

# %%
pd.DataFrame(dict1)
# Out:
#      name  age  marks    role
# 0    Prem   18     85   Rider
# 1   Ashok   17     88   Gamer
# 2  Mayure   17     87  vloger
# 3  Vishal   19     92  Editor

# %%
df=pd.DataFrame(dict1)
len(df)
# Out:
# 4

# %%
df['name'].value_counts()
# Out:
# name
# Prem      1
# Ashok     1
# Mayure    1
# Vishal    1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'role'], dtype='str')

# %%
df
# Out:
#      name  age  marks    role
# 0    Prem   18     85   Rider
# 1   Ashok   17     88   Gamer
# 2  Mayure   17     87  vloger
# 3  Vishal   19     92  Editor

# %%
df.head(4)
# Out:
#      name  age  marks    role
# 0    Prem   18     85   Rider
# 1   Ashok   17     88   Gamer
# 2  Mayure   17     87  vloger
# 3  Vishal   19     92  Editor

# %%
df.tail(4)
# Out:
#      name  age  marks    role
# 0    Prem   18     85   Rider
# 1   Ashok   17     88   Gamer
# 2  Mayure   17     87  vloger
# 3  Vishal   19     92  Editor

# %% [markdown]
# #### Basic operations
#
#   Importing data set from different files
#
#   Importing tabular dataset

# %%
stock_df=pd.read_csv(r"C:\Users\dell\Desktop\data analysis\data set\ETH_1h.csv")

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %% [markdown]
# top 10 rows

# %%
stock_df.head(10)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5  2020-03-13 03-PM  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6  2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7  2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8  2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# 9  2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93  3311080.29

# %% [markdown]
# bottom 5 rows

# %%
stock_df.tail(5)
# Out:
#                    Date  Symbol    Open    High    Low   Close      Volume
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.0  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.0  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.1  275.01   679358.87

# %%
##  number of rows and dataframe
len(stock_df)
# Out:
# 23674

# %% [markdown]
# Access colomn and dataframe

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
## accessing a colomn in a dataframe
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
## Accessing multiple in colomns in a dataframe
stock_df[['Open','Close','Volume']]
# Out:
#          Open   Close      Volume
# 0      129.94  128.71  1940673.93
# 1      119.51  129.94  7579741.09
# 2      124.47  119.51  4898735.81
# 3      124.08  124.47  2753450.92
# 4      124.85  124.08  4461424.71
# ...       ...     ...         ...
# 23669  265.74  272.57  1500282.55
# 23670  268.79  265.74  1702536.85
# 23671  274.83  268.79  3010787.99
# 23672  275.01  274.83   824362.87
# 23673  279.98  275.01   679358.87
#
# [23674 rows x 3 columns]

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.loc[23672]
# Out:
# Date      2017-07-01 12-PM
# Symbol              ETHUSD
# Open                275.01
# High                275.01
# Low                  271.0
# Close               274.83
# Volume           824362.87
# Name: 23672, dtype: object

# %%
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
stock_df.iloc[1,3] #row index and column index
# Out:
# np.float64(132.02)

# %%
stock_df.iloc[3,[2,4]] #multiple column index
# Out:
# Open    124.08
# Low     121.63
# Name: 3, dtype: float64

# %%
stock_df.iloc[2,2:6] # slicing of columns using iloc
# Out:
# Open     124.47
# High     124.85
# Low       115.5
# Close    119.51
# Name: 2, dtype: object

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.iloc[1:6,2:6] #
# Out:
#      Open    High     Low   Close
# 1  119.51  132.02  117.10  129.94
# 2  124.47  124.85  115.50  119.51
# 3  124.08  127.42  121.63  124.47
# 4  124.85  129.51  120.17  124.08
# 5  128.39  128.90  116.06  124.85

# %% [markdown]
# filternig

# %%
stock_df['High'] >130
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 23669     True
# 23670     True
# 23671     True
# 23672     True
# 23673     True
# Name: High, Length: 23674, dtype: bool

# %%
f1=stock_df

# %%
f1
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
f1=stock_df['High'] > 130

stock_gt_130.reset_index(drop=True,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 f1=stock_df['High'] > 130
#       2
# ----> 3 stock_gt_130.reset_index(drop=True,inplace=True)
#
# NameError: name 'stock_gt_130' is not defined
